# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from pathlib import Path

# Reference the file where the CSV is located
weather_csv_path = Path("../Resources/annualweather.csv")

# Import the data into a Pandas DataFrame
weather_df = pd.read_csv(weather_csv_path, encoding="UTF-8")

# %%
weather_reduced_columns = weather_df[["name","datetime","precip"]]
weather_reduced_columns
# Out:
#          name   datetime  precip
# 0    Orlando  2023-05-01    0.00
# 1    Orlando  2023-05-02    0.00
# 2    Orlando  2023-05-03    0.00
# 3    Orlando  2023-05-04    0.00
# 4    Orlando  2023-05-05    0.00
# ..        ...        ...     ...
# 362  Orlando  2024-04-27    0.01
# 363  Orlando  2024-04-28    0.00
# 364  Orlando  2024-04-29    0.00
# 365  Orlando  2024-04-30    0.00
# 366  Orlando  2024-05-01    0.00
#
# [367 rows x 3 columns]

# %%
# Define the path to your CSV file
file_path = ("../Resources/annualweather.csv")  # Modify this path according to your file location

# Read the CSV file into a DataFrame
weather_df = pd.read_csv(file_path)

# Convert the 'datetime' column to pandas datetime format
weather_df['datetime'] = pd.to_datetime(weather_df['datetime'])

# Extract month from the 'datetime' column
weather_df['Month'] = weather_df['datetime'].dt.month

# Group by month and calculate monthly statistics
monthly_data = weather_df.groupby('Month').agg({
    'temp': 'mean',   # Average temperature
    'precip': 'sum',  # Total precipitation
    # Add more statistics as needed
}).reset_index()

# Rename month numbers to month names
month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}
monthly_data['Month'] = monthly_data['Month'].map(month_names)

# Display the aggregated monthly data
print(monthly_data)
# Out:
#         Month       temp  precip
# 0     January  61.367742   1.340
# 1    February  62.717241   2.743
# 2       March  70.596774   1.510
# 3       April  71.890000   0.982
# 4         May  77.515625   4.530
# 5        June  80.553333   7.104
# 6        July  82.874194   6.457
# 7      August  84.348387   6.650
# 8   September  80.983333   6.448
# 9     October  75.293548   2.330
# 10   November  69.016667   5.318
# 11   December  63.861290   4.593

# %%
import matplotlib.pyplot as plt

# Data
months = ['May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March', 'April']
temperatures = [77.52, 80.55, 82.87, 84.35, 80.98, 75.29, 69.02, 63.86, 61.37, 62.72, 70.60, 71.89]
precipitation = [4.53, 7.10, 6.46, 6.65, 6.45, 2.33, 5.32, 4.59, 1.34, 2.74, 1.51, 0.98]

# Function to create a chart
def create_chart(x, y, title, xlabel, ylabel, color, marker=None, linestyle=None):
    plt.figure(figsize=(10, 6))
    if marker and linestyle:
        plt.plot(x, y, marker=marker, color=color, linestyle=linestyle)
    else:
        plt.bar(x, y, color=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Create a bar chart for temperatures
create_chart(months, temperatures, 'Average Monthly Temperature', 'Month', 'Temperature (F)', 'skyblue')

# Create a line plot for precipitation
create_chart(months, precipitation, 'Monthly Precipitation', 'Month', 'Precipitation (inches)', 'orange', marker='o', linestyle='-')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Using double backslashes:
google_trend_df = pd.read_csv("../Resources/GoogleTrendsTimeline.csv")

# Using raw string literals:
# dataset = pd.read_csv(r"C:\Users\gomes\OneDrive\Documents\Project-1\Resources\GoogleTrendsTimeline.csv")
google_trend_df
# Out:
#       Datetime   florida mall  Disney Parks  The Mall at Millenia
# 0   2023-05-07             30            37                    11
# 1   2023-05-14             26            38                    12
# 2   2023-05-21             28            39                    13
# 3   2023-05-28             32            41                    11
# 4   2023-06-04             29            40                    13
# 5   2023-06-11             31            41                    11
# 6   2023-06-18             30            47                    13
# 7   2023-06-25             32            37                    13
# 8   2023-07-02             38            40                    16
# 9   2023-07-09             33           100                    14
# 10  2023-07-16             33            41                    13
# 11  2023-07-23             37            41                    15
# 12  2023-07-30             36            35                    15
# ...

# %%
google_trend_df.columns
# Out:
# Index(['Datetime', ' florida mall', 'Disney Parks', 'The Mall at Millenia'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
type(google_trend_df['Datetime'][0])
# Out:
# str

# %%
google_trend_df['Datetime']= pd.to_datetime(google_trend_df['Datetime'])

# %%
#google_trend_df.set_index('Datetime',inplace=True)

# %%
google_trend_df
# Out:
#      Datetime   florida mall  Disney Parks  The Mall at Millenia
# 0  2023-05-07             30            37                    11
# 1  2023-05-14             26            38                    12
# 2  2023-05-21             28            39                    13
# 3  2023-05-28             32            41                    11
# 4  2023-06-04             29            40                    13
# 5  2023-06-11             31            41                    11
# 6  2023-06-18             30            47                    13
# 7  2023-06-25             32            37                    13
# 8  2023-07-02             38            40                    16
# 9  2023-07-09             33           100                    14
# 10 2023-07-16             33            41                    13
# 11 2023-07-23             37            41                    15
# 12 2023-07-30             36            35                    15
# ...

# %%
google_trend_df['Month']= google_trend_df['Datetime'].dt.month
google_trend_df['Year']= google_trend_df['Datetime'].dt.year

# %%
google_trend_df
# Out:
#      Datetime   florida mall  Disney Parks  The Mall at Millenia  Month
# 0  2023-05-07             30            37                    11      5
# 1  2023-05-14             26            38                    12      5
# 2  2023-05-21             28            39                    13      5
# 3  2023-05-28             32            41                    11      5
# 4  2023-06-04             29            40                    13      6
# 5  2023-06-11             31            41                    11      6
# 6  2023-06-18             30            47                    13      6
# 7  2023-06-25             32            37                    13      6
# 8  2023-07-02             38            40                    16      7
# 9  2023-07-09             33           100                    14      7
# 10 2023-07-16             33            41                    13      7
# 11 2023-07-23             37            41                    15      7
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Your data frame
google_trend_df = pd.read_csv("../Resources/GoogleTrendsTimeline.csv")

# Convert 'Datetime' column to datetime type
google_trend_df['Datetime'] = pd.to_datetime(google_trend_df['Datetime'])

# Extract month and year from datetime
google_trend_df['Month-Year'] = google_trend_df['Datetime'].dt.to_period('M')

# Group by month-year and calculate the mean of 'Florida Mall' visits
monthly_data = google_trend_df.groupby('Month-Year')['Disney Parks'].mean()

# Plotting the bar graph
plt.figure(figsize=(10, 6))
monthly_data.plot(kind='bar', color='skyblue')
plt.title('Average Monthly Visits to Disney Parks')
plt.xlabel('Month-Year')
plt.ylabel('Average Visits')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Your data frame
google_trend_df = pd.read_csv("../Resources/GoogleTrendsTimeline.csv")

# Convert 'Datetime' column to datetime type
google_trend_df['Datetime'] = pd.to_datetime(google_trend_df['Datetime'])

# Extract month and year from datetime
google_trend_df['Month-Year'] = google_trend_df['Datetime'].dt.to_period('M')

# Group by month-year and calculate the mean of 'Florida Mall' visits
monthly_data = google_trend_df.groupby('Month-Year')[' florida mall'].mean()

# Plotting the bar graph
plt.figure(figsize=(10, 6))
monthly_data.plot(kind='bar', color='skyblue')
plt.title('Average Monthly Visits to florida mall')
plt.xlabel('Month-Year')
plt.ylabel('Average Visits')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Your data frame
google_trend_df = pd.read_csv("../Resources/GoogleTrendsTimeline.csv")

# Convert 'Datetime' column to datetime type
google_trend_df['Datetime'] = pd.to_datetime(google_trend_df['Datetime'])

# Extract month and year from datetime
google_trend_df['Month-Year'] = google_trend_df['Datetime'].dt.to_period('M')

# Group by month-year and calculate the mean of 'Florida Mall' visits
monthly_data = google_trend_df.groupby('Month-Year')['The Mall at Millenia'].mean()

# Plotting the bar graph
plt.figure(figsize=(10, 6))
monthly_data.plot(kind='bar', color='skyblue')
plt.title('Average Monthly Visits The Mall at Millenia')
plt.xlabel('Month-Year')
plt.ylabel('Average Visits')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
