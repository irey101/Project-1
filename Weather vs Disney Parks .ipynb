# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
weather_data = Path("../Resources/annualweather.csv")

# Import the data into a Pandas DataFrame
weather_df = pd.read_csv(weather_data, encoding="UTF-8")
weather_df
# Out:
#          name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0    Orlando   2023-05-01     86.0     64.7  74.1          84.8          64.7
# 1    Orlando   2023-05-02     87.1     66.6  76.4          86.5          66.6
# 2    Orlando   2023-05-03     86.0     69.0  75.5          82.7          69.0
# 3    Orlando   2023-05-04     86.0     63.7  75.3          83.3          63.7
# 4    Orlando   2023-05-05     87.0     65.9  75.2          87.1          65.9
# ..        ...         ...      ...      ...   ...           ...           ...
# 362  Orlando   2024-04-27     82.3     65.2  72.9          82.7          65.2
# 363  Orlando   2024-04-28     80.9     64.4  72.7          80.9          64.4
# 364  Orlando   2024-04-29     85.6     61.3  73.2          85.0          61.3
# 365  Orlando   2024-04-30     84.7     66.0  74.5          86.4          66.0
# 366  Orlando   2024-05-01     89.5     66.0  76.7          90.3          66.0
#
# ...

# %%
weather_reduced_columns = weather_df[["name","datetime","precip"]]
weather_reduced_columns
# Out:
#          name    datetime  precip
# 0    Orlando   2023-05-01    0.00
# 1    Orlando   2023-05-02    0.00
# 2    Orlando   2023-05-03    0.00
# 3    Orlando   2023-05-04    0.00
# 4    Orlando   2023-05-05    0.00
# ..        ...         ...     ...
# 362  Orlando   2024-04-27    0.01
# 363  Orlando   2024-04-28    0.00
# 364  Orlando   2024-04-29    0.00
# 365  Orlando   2024-04-30    0.00
# 366  Orlando   2024-05-01    0.00
#
# [367 rows x 3 columns]

# %%
# Filter data so it only includes patrons who checked out at least one item
weather_df = pd.DataFrame(weather_df.loc[weather_df['precip']>0,:])

# Split up our data into groups based upon 'Patron Type Definition'
date_groups = weather_df.groupby('datetime')

# Find out how many of each patron type borrowed library items
precip_count = date_groups['precip'].count()

# Chart our data, give it a title, and label the axes
precip_chart = precip_count.plot(kind="bar", title="Rainy Days")
patron_chart.set_xlabel("Date")
patron_chart.set_ylabel("Inches of Rain")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 12
#      10 # Chart our data, give it a title, and label the axes
#      11 precip_chart = precip_count.plot(kind="bar", title="Rainy Days")
# ---> 12 patron_chart.set_xlabel("Date")
#      13 patron_chart.set_ylabel("Inches of Rain")
#      15 plt.show()
#
# NameError: name 'patron_chart' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import json
import matplotlib.pyplot as plt

# Sample JSON data
json_data = '''
{
 "queryCost": 1,
 "latitude": 28.5382,
 "longitude": -81.3774,
 "resolvedAddress": "Orlando, FL, United States",
 "address": "Orlando",
 "timezone": "America/New_York",
 "tzoffset": -4,
 "description": "Similar temperatures continuing with a chance of rain multiple days.",
 "days": [
  {
   "datetime": "2024-05-09",
   "datetimeEpoch": 1715227200,
   "tempmax": 95,
   "tempmin": 75.5,
   "temp": 84.2,
   "feelslikemax": 98.5,
   "feelslikemin": 75.5,
   "feelslike": 86.4,
   "dew": 68.7,
   "humidity": 62.4,
   "precip": 0.031,
   "precipprob": 9,
   "precipcover": 4.17,
   "preciptype": [
    "rain"
   ]
  }
 ]
}
'''

# Parse JSON data
weather_data = json.loads(json_data)

# Extract dates and probability of rain
dates = [day['datetime'] for day in weather_data['days']]
rain_probability = [day['precipprob'] for day in weather_data['days']]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(dates, rain_probability, color='green', label='Probability of Rain')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Probability of Rain (%)')
plt.title('Probability of Rain in Orlando')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
from IPython.display import HTML

# Embed the Google Trends URL
url = """
<iframe width="600" height="400" src="https://trends.google.com:443/trends/embed/explore/TIMESERIES?req=%7B%22comparisonItem%22%3A%5B%7B%22keyword%22%3A%22Orlando%20Parks%22%2C%22geo%22%3A%22US%22%2C%22time%22%3A%22today%203-m%22%7D%2C%7B%22keyword%22%3A%22%2Fm%2F0c6sd3%22%2C%22geo%22%3A%22US%22%2C%22time%22%3A%22today%203-m%22%7D%5D%2C%22category%22%3A0%2C%22property%22%3A%22%22%7D&tz=-300&hl=pt-BR" frameborder="0" scrolling="0" style="border: none;"></iframe>
"""

# Display the embedded URL
HTML(url)
# Out:
# <iframe width="600" height="400" src="https://trends.google.com:443/trends/embed/explore/TIMESERIES?req=%7B%22comparisonItem%22%3A%5B%7B%22keyword%22%3A%22Orlando%20Parks%22%2C%22geo%22%3A%22US%22%2C%22time%22%3A%22today%203-m%22%7D%2C%7B%22keyword%22%3A%22%2Fm%2F0c6sd3%22%2C%22geo%22%3A%22US%22%2C%22time%22%3A%22today%203-m%22%7D%5D%2C%22category%22%3A0%2C%22property%22%3A%22%22%7D&tz=-300&hl=pt-BR" frameborder="0" scrolling="0" style="border: none;"></iframe>
